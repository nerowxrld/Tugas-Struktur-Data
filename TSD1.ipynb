# %% [markdown]
# <a href="https://colab.research.google.com/github/nerowxrld/Tugas-Struktur-Data/blob/main/TSD1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# 1. Input 10 nilai mahasiswa (disimpan dalam array/list)
nilai = []

for i in range(10):
    n = int(input(f"Masukkan nilai mahasiswa ke-{i+1}: "))
    nilai.append(n)

# 2. Menampilkan semua nilai
print("\nData Nilai Mahasiswa:", nilai)

# 3. Nilai tertinggi dan terendah
nilai_tertinggi = max(nilai)
nilai_terendah = min(nilai)

print("Nilai tertinggi:", nilai_tertinggi)
print("Nilai terendah:", nilai_terendah)

# 4. Menghitung rata-rata
rata_rata = sum(nilai) / len(nilai)
print("Rata-rata nilai:", rata_rata)

# 5. Menghitung jumlah mahasiswa lulus
lulus = 0
tidak_lulus = 0

for n in nilai:
    if n >= 60:
        lulus += 1
    else:
        tidak_lulus += 1

print("Jumlah mahasiswa lulus:", lulus)
print("Jumlah mahasiswa tidak lulus:", tidak_lulus)

# 6. Grafik nilai tertinggi dan terendah
label = ['Nilai Tertinggi', 'Nilai Terendah']
data = [nilai_tertinggi, nilai_terendah]

plt.figure()
plt.bar(label, data)
plt.title("Perbandingan Nilai Tertinggi dan Terendah")
plt.ylabel("Nilai")
plt.show()

# 7. Grafik data kelulusan
label_kelulusan = ['Lulus', 'Tidak Lulus']
data_kelulusan = [lulus, tidak_lulus]

plt.figure()
plt.pie(data_kelulusan, labels=label_kelulusan, autopct='%1.1f%%')
plt.title("Persentase Kelulusan Mahasiswa")
plt.show()
# Out:
# Masukkan nilai mahasiswa ke-1: 50
# Masukkan nilai mahasiswa ke-2: 80
# Masukkan nilai mahasiswa ke-3: 60
# Masukkan nilai mahasiswa ke-4: 65
# Masukkan nilai mahasiswa ke-5: 90
# Masukkan nilai mahasiswa ke-6: 95
# Masukkan nilai mahasiswa ke-7: 45
# Masukkan nilai mahasiswa ke-8: 75
# Masukkan nilai mahasiswa ke-9: 89
# Masukkan nilai mahasiswa ke-10: 100
#
# Data Nilai Mahasiswa: [50, 80, 60, 65, 90, 95, 45, 75, 89, 100]
# Nilai tertinggi: 100
# Nilai terendah: 45
# Rata-rata nilai: 74.9
# Jumlah mahasiswa lulus: 8
# Jumlah mahasiswa tidak lulus: 2
